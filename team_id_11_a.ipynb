# %% [markdown]
# # PART-A: Image Captioning with CNN Encoder and RNN Decoder
#
# This notebook implements an image captioning model using a Convolutional Neural Network (CNN) as an encoder and a Long Short-Term Memory (LSTM)-based Recurrent Neural Network (RNN) as a decoder. The model aims to generate descriptive captions for images, bridging computer vision and natural language processing.
#
# This notebook is divided into 6 sections:
# - Importing and Setup
# - Preprocessing
# - Model Creation
# - Model Evalution
# - Evalution and Results
# - Final Output

# %% [markdown]
# ## Importing and Setup
# In this section, we import necessary libraries and set up the environment for building the image captioning model. This includes defining functions for preprocessing captions, loading the dataset, and creating a vocabulary.
#
# - **Imports**: Libraries such as os, torch, torch.utils.data, transforms, pandas, Image, numpy, and json are imported.
#
# - **Vocabulary Builder**: The build_vocab function tokenizes captions and creates a vocabulary based on word frequency, with a threshold to filter infrequent words.
#
# - **Caption Tokenization**: Captions are converted into tokenized sequences using the tokenize_captions function, which also applies padding for uniform length.
#
# - **Dataset Loading**: Train, test, and validation datasets are loaded from CSV files containing image filenames and captions.
#
# - **Vocabulary Setup**: Captions from the train and validation datasets are combined, and the vocabulary is built and applied to tokenize the captions.
#
# - **Print Dataset Information**: Display the sizes of the train, test, and validation datasets, along with the vocabulary size.

# %%
import os
import torch 
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
import pandas as pd
from PIL import Image

# %%
import numpy as np
import json
from collections import Counter

def build_vocab(captions, threshold=5):
    # Tokenize captions
    word_counts = Counter()
    max_caption_len = 0
    for caption in captions:
        caption_len = 0
        caption = '<start>' + caption + '<end>'
        for word in caption.split(' '):
            word_counts[word] += 1
            caption_len +=1
        max_caption_len = max(max_caption_len, caption_len)
            
    # Create vocabulary
    words = [word for word, count in word_counts.items() if count >= threshold]
    word2idx = {word: idx + 1 for idx, word in enumerate(words)}  # Start indexing from 1
    word2idx['<unk>'] = 0  # Add special token for unknown words
    idx2word = {idx: word for word, idx in word2idx.items()}
    
    return word2idx, idx2word, max_caption_len


def tokenize_captions(captions, word2idx, max_length):
    caption_tokens = []
    for caption in captions:
        tokens = [word2idx.get(word, word2idx['<unk>']) for word in caption.split(' ')]
        tokens = tokens[:max_length] + [0] * (max_length - len(tokens))  # Pad sequences
        caption_tokens.append(tokens)
    return np.array(caption_tokens)

# %%
#  Read train.csv
train_df = pd.read_csv('/kaggle/input/image-caption/custom_captions_dataset/train.csv')

# Read test.csv
test_df = pd.read_csv('/kaggle/input/image-caption/custom_captions_dataset/test.csv')

# Read val.csv
val_df = pd.read_csv('/kaggle/input/image-caption/custom_captions_dataset/val.csv')

# Function to preprocess captions (similar to your approach)
def preprocess_caption(caption):
    return ' '.join(caption.strip().split(' ')[:40])  # Truncate to first 40 words


# Access image names and captions
train_image_names = train_df['filename'].tolist()
train_captions = train_df['caption'].tolist()
for i in range(len(train_captions)):
    train_captions[i]=preprocess_caption(train_captions[i])

test_image_names = test_df['filename'].tolist()
test_captions = test_df['caption'].tolist()
for i in range(len(test_captions)):
    test_captions[i]=preprocess_caption(test_captions[i])

val_image_names = val_df['filename'].tolist()
val_captions = val_df['caption'].tolist()
for i in range(len(val_captions)):
    val_captions[i]=preprocess_caption(val_captions[i])

captions = []
captions = train_captions + val_captions


print(len(train_captions), len(val_captions), len(captions))
print(f"Train Size: {train_df.shape}")
print(f"Test Size: {test_df.shape}")
print(f"Val Size: {val_df.shape}")
# Out:
# 5715 946 6661
# Train Size: (5715, 3)
# Test Size: (928, 3)
# Val Size: (946, 3)

# %%
max_length=0
# Build vocabulary
word2idx, idx2word, max_length = build_vocab(captions, 3)

max_length=40

# Tokenize captions
caption_tokens = tokenize_captions(captions, word2idx, max_length)

print("Vocabulary size:", len(word2idx))
# print("Word to index mapping:", word2idx)
# print("Index to word mapping:", idx2word)
print("Tokenized captions:")
print(caption_tokens)
# Out:
# Vocabulary size: 4222
# Tokenized captions:
# [[262   2   3 ...  20   2   4]
#  [ 38  19  32 ...   6   7   2]
#  [262  53  48 ...   5  64 312]
#  ...
#  [ 38   5   7 ...   5 206  79]
#  [  0  23  79 ...   9   7 104]
#  [709   5   7 ... 134   5 195]]

# %% [markdown]
# ## Preprocessing
# This section defines a custom dataset class and applies transformations to preprocess images and captions for training the image captioning model.

# %% [markdown]
# **Custom Dataset Class**: The CustomDataset class is defined to handle the dataset, taking a pandas dataframe, image directory path, vocabulary mapping word2idx, maximum caption length max_length, and optional transform for image preprocessing.
#
# **Dataset Length**: The __len__ method returns the length of the dataset.
#
# **Data Loading**: The __getitem__ method loads an image and its corresponding caption at the given index. It also tokenizes the caption, pads it to the maximum length, and returns the image, original caption, tokenized caption, and caption length.

# %%
class CustomDataset(Dataset):
    def __init__(self, dataframe, image_dir, word2idx, max_length, transform=None):
        self.dataframe = dataframe
        self.image_dir = image_dir
        self.transform = transform
        self.word2idx = word2idx
        self.max_length = max_length

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_name = self.dataframe.iloc[idx, 1]  
        img_path = os.path.join(self.image_dir, img_name)
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)

        caption = self.dataframe.iloc[idx, 2] 
        caption_length = len(caption.split())
        
        # Tokenize caption
        tokens = [self.word2idx.get(word, self.word2idx['<unk>']) for word in caption.split(' ')]
        tokens = tokens[:self.max_length] + [0] * (self.max_length - len(tokens))  # Pad sequences
        tokens = torch.tensor(tokens)
        return image,caption, tokens, caption_length

# %% [markdown]
# **Image Preprocessing**: Images are resized and center-cropped to 224x224 pixels, converted to tensors, and normalized using mean [0.485, 0.456, 0.406] and standard deviation [0.229, 0.224, 0.225].

# %%
# resize the image
transform = transforms.Compose([
    transforms.Resize(224),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    
])

# %% [markdown]
# **Dataset Creation**: Datasets for training, testing, and validation are created using the CustomDataset class with the specified transformations and directories.
#
# **Data Loaders**: Data loaders are created for each dataset with a specified batch size, enabling efficient loading and processing of data during training and evaluation.
#
# **Dataset Information**: Information about the sizes of the train, test, and validation datasets is printed to provide an overview of the dataset.

# %%
train_image_dir = '/kaggle/input/image-caption/custom_captions_dataset/train'  
test_image_dir = '/kaggle/input/image-caption/custom_captions_dataset/test'
val_image_dir = '/kaggle/input/image-caption/custom_captions_dataset/val'

# Create datasets
train_dataset = CustomDataset(train_df, train_image_dir, word2idx, max_length, transform=transform)
test_dataset = CustomDataset(test_df, test_image_dir, word2idx, max_length, transform=transform)
val_dataset = CustomDataset(val_df, val_image_dir, word2idx, max_length, transform=transform)

# Define batch size
batch_size = 64

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size)
val_loader = DataLoader(val_dataset, batch_size=batch_size)

# Optionally, print some information about the datasets
print(f"Train Dataset Size: {len(train_dataset)}")
print(f"Test Dataset Size: {len(test_dataset)}")
print(f"Validation Dataset Size: {len(val_dataset)}")
# Out:
# Train Dataset Size: 5715
# Test Dataset Size: 928
# Validation Dataset Size: 946

# %% [markdown]
# ## Model Creation
#
# In this section, we define the architecture of the image captioning model, consisting of a CNN encoder and an LSTM-based RNN decoder. The encoder processes input images to extract meaningful features, which are then used by the decoder to generate captions.
#
# - **CNN Encoder**: Utilizes a pre-trained ResNet-50 model to extract image features. The extracted features are then passed through a linear layer and batch normalization to generate an embedding.
#
# - **RNN Decoder**: Uses an embedding layer to convert tokenized captions into embedded representations. The LSTM-based decoder then generates captions based on the embedded representations, producing a sequence of words.

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torch.nn.utils.rnn import pack_padded_sequence

# CNN Encoder
class EncoderCNN(nn.Module):
    def __init__(self, embed_size):
        super(EncoderCNN, self).__init__()
        resnet = models.resnet50(pretrained=True)  # Pre-trained ResNet-50
        modules = list(resnet.children())[:-1]  # Remove the last fully connected layer
        self.resnet = nn.Sequential(*modules)
        self.embed = nn.Linear(resnet.fc.in_features, embed_size)
        self.bn = nn.BatchNorm1d(embed_size, momentum=0.01)

    def forward(self, images):
        with torch.no_grad():
            features = self.resnet(images)
        features = features.reshape(features.size(0), -1)
        features = self.bn(self.embed(features))
        return features

# RNN Decoder
class DecoderRNN(nn.Module):
    def __init__(self, embed_size, hidden_size, vocab_size, num_layers, max_seq_length=20):
        super(DecoderRNN, self).__init__()
        self.embed = nn.Embedding(vocab_size, embed_size)
        self.lstm = nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, vocab_size)
        self.max_seg_length = max_seq_length

    def forward(self, features, captions, lengths):
        embeddings = self.embed(captions)
        embeddings = torch.cat((features.unsqueeze(1), embeddings), 1)
        packed = pack_padded_sequence(embeddings, lengths, batch_first=True, enforce_sorted=False) 
        hiddens, _ = self.lstm(packed)
        outputs = self.linear(hiddens[0])
        return outputs

    def sample(self, features, states=None):
        sampled_ids = []
        inputs = features.unsqueeze(1)
        for i in range(self.max_seg_length):
            hiddens, states = self.lstm(inputs, states)
            outputs = self.linear(hiddens.squeeze(1))
            _, predicted = outputs.max(1)
            sampled_ids.append(predicted)
            inputs = self.embed(predicted).unsqueeze(1)
        sampled_ids = torch.stack(sampled_ids, 1)
        return sampled_ids

# %%
# Initialize the encoder and decoder
embed_size = 256
hidden_size = 512
vocab_size = len(word2idx)
num_layers = 1
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size, num_layers, max_length)

# Move models to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)
# Out:
# DecoderRNN(
#   (embed): Embedding(4222, 256)
#   (lstm): LSTM(256, 512, batch_first=True)
#   (linear): Linear(in_features=512, out_features=4222, bias=True)
# )

# %%
# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
params = list(decoder.parameters()) + list(encoder.embed.parameters())
optimizer = torch.optim.Adam(params, lr=0.001)

# %% [markdown]
# ## Model Training
#
# This section details the training process of the image captioning model, including the training loop, loss computation, and optimization steps.
#
# - **Training Loop**: The model is trained for a specified number of epochs. For each epoch, the total loss is calculated as the sum of losses over all batches.
#
# - **Forward Pass**: The encoder processes input images to extract features, which are then fed into the decoder along with tokenized captions to generate outputs.
#
# - **Loss Computation**: The CrossEntropyLoss is used to compute the loss between the predicted outputs and the ground truth captions.
#
# - **Backward Pass and Optimization**: The optimizer is used to update the model parameters based on the computed gradients.
#
# - **Model Evaluation**: The trained model can be evaluated using the test dataset to generate captions for unseen images.
#
# - **Model Saving**: Optionally, the trained model can be saved to disk for future use.

# %%
# Training loop
num_epochs = 20
for epoch in range(num_epochs):
    total_loss = 0
    for i, (images, cap, captions, leng) in enumerate(train_loader):
        lengths = [max_length]*len(leng)
        images = images.to(device)
        captions = captions.to(device)
        targets = pack_padded_sequence(captions, lengths, batch_first=True, enforce_sorted=False)[0]
        
        # Forward pass
        features = encoder(images)
        outputs = decoder(features, captions, lengths)
        
        # Compute loss
        loss = criterion(outputs, targets)
        
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        
        # Print progress
        if (i+1) % 50 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}')
    
    # Print epoch-wise loss
    print(f'Epoch [{epoch+1}/{num_epochs}], Average Loss: {total_loss/len(train_loader):.4f}')

# Optionally, save the trained model
torch.save(encoder.state_dict(), 'encoder.pth')
torch.save(decoder.state_dict(), 'decoder.pth')
# Out:
# Epoch [1/20], Step [50/90], Loss: 5.1017
# Epoch [1/20], Average Loss: 5.1573
# Epoch [2/20], Step [50/90], Loss: 4.1889
# Epoch [2/20], Average Loss: 4.0098
# Epoch [3/20], Step [50/90], Loss: 3.7819
# Epoch [3/20], Average Loss: 3.6200
# Epoch [4/20], Step [50/90], Loss: 3.5381
# Epoch [4/20], Average Loss: 3.3794
# Epoch [5/20], Step [50/90], Loss: 3.3499
# Epoch [5/20], Average Loss: 3.2043
# Epoch [6/20], Step [50/90], Loss: 3.1943
# Epoch [6/20], Average Loss: 3.0600
# Epoch [7/20], Step [50/90], Loss: 3.0582
# Epoch [7/20], Average Loss: 2.9302
# Epoch [8/20], Step [50/90], Loss: 2.9293
# Epoch [8/20], Average Loss: 2.8106
# Epoch [9/20], Step [50/90], Loss: 2.8105
# Epoch [9/20], Average Loss: 2.7008
# Epoch [10/20], Step [50/90], Loss: 2.6946
# Epoch [10/20], Average Loss: 2.5963
# Epoch [11/20], Step [50/90], Loss: 2.5914
# Epoch [11/20], Average Loss: 2.4955
# Epoch [12/20], Step [50/90], Loss: 2.4987
# Epoch [12/20], Average Loss: 2.4046
# Epoch [13/20], Step [50/90], Loss: 2.4179
# Epoch [13/20], Average Loss: 2.3218
# Epoch [14/20], Step [50/90], Loss: 2.3244
# Epoch [14/20], Average Loss: 2.2341
# Epoch [15/20], Step [50/90], Loss: 2.2259
# Epoch [15/20], Average Loss: 2.1410
# Epoch [16/20], Step [50/90], Loss: 2.1329
# Epoch [16/20], Average Loss: 2.0560
# Epoch [17/20], Step [50/90], Loss: 2.0499
# Epoch [17/20], Average Loss: 1.9767
# Epoch [18/20], Step [50/90], Loss: 1.9675
# Epoch [18/20], Average Loss: 1.9020
# Epoch [19/20], Step [50/90], Loss: 1.9129
# Epoch [19/20], Average Loss: 1.8284
# Epoch [20/20], Step [50/90], Loss: 1.8263
# Epoch [20/20], Average Loss: 1.7545

# %%
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size, num_layers, max_length)
encoder.load_state_dict(torch.load('encoder.pth'))
decoder.load_state_dict(torch.load('decoder.pth'))

# Set the model to evaluation mode
encoder.eval()
decoder.eval()

# Move models to GPU if available
encoder.to(device)
decoder.to(device)
predicted_captions = []

# Iterate through test dataset
for images, ground_truths, _, _ in test_loader:
    images = images.to(device)
    
    # Extract features using the encoder
    with torch.no_grad():
        features = encoder(images)
    
    # Generate captions using the decoder
    sampled_ids = decoder.sample(features)
    
    # Decode the predicted captions
    sampled_ids = sampled_ids.cpu().numpy()
    for sample_id in sampled_ids:
        predicted_caption = []
#         predicted_caption = ['<start>']
        for word_id in sample_id:
            if word_id==0:
                continue
            word = idx2word[word_id]
            if word == '<end>': 
                break
            predicted_caption.append(word)
#         predicted_caption.append('<end>') 
        predicted_captions.append(' '.join(predicted_caption))

# %% [markdown]
# ## Evalution and Results
#
# This section evaluates the performance of the trained image captioning model by generating captions for a sample of images from the test dataset and calculating evaluation metrics such as CIDEr, ROUGE-L, and SPICE scores.
#
# - **Sample Image and Caption Pairs**: Three images from the test dataset are selected, and captions are generated using the trained model. These image-caption pairs are displayed to showcase the model's captioning capability.
#
# - **Captioning Test Dataset**: Using the trained model, captions are generated for the entire test dataset. These generated captions are then used to calculate evaluation metrics, providing insights into the quality of the model's captions compared to ground truth captions.
#
# - **Evaluation Metrics**: CIDEr, ROUGE-L, and SPICE scores are computed based on the generated captions and ground truth captions from the test dataset, quantifying the similarity and quality of the generated captions.

# %%
 import matplotlib.pyplot as plt
import numpy as np
# Print some of the predicted captions
for i in range(5):
        # Assuming you have a test dataset with images
    image, truth, _,_ = test_dataset[i]  # Replace `index` with the index of the image you want to display
    image = image.permute(1, 2, 0)  # Move channel dimension to the last position
    image = (image.numpy() * 255).astype(np.uint8)  # Convert from torch tensor to numpy array and scale pixel values

    # Display the image
#     plt.imshow(image)
#     plt.axis('off')
#     plt.show()
    print(f"Ground Truth {i+1}: {truth}")
    print(len(predicted_captions[i]))
    print(f'Predicted Caption {i+1}: {predicted_captions[i]}\n\n')
# Out:
# Ground Truth 1: A large building with bars on the windows in front of it. There is people walking in front of the building. There is a street in front of the building with many cars on it.
# 187
# Predicted Caption 1: The image is of a city street. There is a street light in the street with a large The building is painted yellow and black. There is a car parked on the side of the street. There are many
#
#
# Ground Truth 2: A person is skiing through the snow. There is loose snow all around them from him jumping. The person is wearing a yellow snow suit. The person is holding two ski poles in their hands.
# 194
# Predicted Caption 2: A person is standing on a beach on a sunny day. The man is wearing a black jacket and blue jean pants. The man is wearing a black jacket and black pants. The person is wearing a black jacket and
#
#
# Ground Truth 3: There is a bed in a room against a wall. There is a brown blanket on top of the bed. There is a small brown book shelf next to the bed. There is a picture hanging on the wall above the shelf.
# 192
# Predicted Caption 3: This picture is taken inside of a living room of a home. A small white t.v. is sitting on a desk with a white painted wall behind it. There is a white and black keyboard sitting on the desk in
#
#
# Ground Truth 4: A black and red train is on the tracks and has steam coming out off of it. There is another train next to the first train that is orange. There is an overpass over the train tracks with cars on it.
# 213
# Predicted Caption 4: The train is pulling into the station. The train is yellow and black. The train is pulling into the station. The train is yellow and black. The train is pulling into the station. The train is yellow and black. The
#
#
# Ground Truth 5: A white and yellow public transportation bus with "122" on front is stopped with it's doors open. There is a gray car on the street beside the bus. Behind the car there is a  building with an "Urban Outfitters" on the first floor.
# 166
# Predicted Caption 5: A bus is parked on the street. The bus is white and has a black and white There is a red and white train on the tracks. There is a red train on the track.  There is a

# %%
# creating json files to store the captions in the format needed for using evaluation metrics

import json

imags_json=[]
for idx,path in enumerate(test_image_names):
    imags_json.append({
        "license": 1,
        "url": '/kaggle/input/image-caption/custom_captions_dataset'+test_image_names[i],
        "file_name": "COCO_val2014_000000572233.jpg",
        "id": idx,
        "width": 640,
        "date_captured": "2013-11-25 14:48:33",
        "height": 427
    }
    )

# Assuming actual_captions and generated_captions are lists of captions
actual_captions_json = []
for idx, caption in enumerate(test_captions):
    actual_captions_json.append({
        "image_id": idx,  # Assuming image IDs start from 0 and are sequential
        "id": idx,  # Assuming IDs are unique and sequential
        "caption": test_captions[idx]
    })

generated_captions_json = []
for idx, caption in enumerate(predicted_captions):
    generated_captions_json.append({
        "image_id": idx,  # Assuming image IDs start from 0 and are sequential
        "caption": predicted_captions[idx]
    })


# Create a new JSON object
data = {
    "info": {
        "description": "This is stable 1.0 version of the 2014 MS COCO dataset.",
        "url": "http://mscoco.org",
        "version": "1.0",
        "year": 2014,
        "contributor": "Microsoft COCO group",
        "date_created": "2015-01-27 09:11:52.357475"
    },
    "images": imags_json,
    "type": "captions",
    "licenses": [
        {
            "url": "http://creativecommons.org/licenses/by-nc-sa/2.0/",
            "id": 1,
            "name": "Attribution-NonCommercial-ShareAlike License"
        },
        {
            "url": "http://creativecommons.org/licenses/by-nc/2.0/",
            "id": 2,
            "name": "Attribution-NonCommercial License"
        },
        {
            "url": "http://creativecommons.org/licenses/by-nc-nd/2.0/",
            "id": 3,
            "name": "Attribution-NonCommercial-NoDerivs License"
        },
        {
            "url": "http://creativecommons.org/licenses/by/2.0/",
            "id": 4,
            "name": "Attribution License"
        },
        {
            "url": "http://creativecommons.org/licenses/by-sa/2.0/",
            "id": 5,
            "name": "Attribution-ShareAlike License"
        },
        {
            "url": "http://creativecommons.org/licenses/by-nd/2.0/",
            "id": 6,
            "name": "Attribution-NoDerivs License"
        },
        {
            "url": "http://flickr.com/commons/usage/",
            "id": 7,
            "name": "No known copyright restrictions"
        },
        {
            "url": "http://www.usa.gov/copyright.shtml",
            "id": 8,
            "name": "United States Government Work"
        }
    ],
    "annotations": actual_captions_json  # Use actual_captions_json or generated_captions_json here
}

data2 = generated_captions_json

# Save the JSON to a file
with open('captions.json', 'w') as f:
    json.dump(data, f, indent=4)
    
# Save the JSON to a file
with open('gen_captions.json', 'w') as ff:
    json.dump(data2, ff, indent=4)

# %%
# !pip install pycocoevalcap
# Out:
# Requirement already satisfied: pycocoevalcap in /opt/conda/lib/python3.10/site-packages (1.2)
# Requirement already satisfied: pycocotools>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from pycocoevalcap) (2.0.7)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from pycocotools>=2.0.2->pycocoevalcap) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pycocotools>=2.0.2->pycocoevalcap) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.16.0)

# %%
# !pip install pycocotools
# Out:
# Requirement already satisfied: pycocotools in /opt/conda/lib/python3.10/site-packages (2.0.7)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from pycocotools) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)

# %%
from pycocoevalcap.tokenizer.ptbtokenizer import PTBTokenizer
from pycocoevalcap.bleu.bleu import Bleu
from pycocoevalcap.meteor.meteor import Meteor
from pycocoevalcap.rouge.rouge import Rouge
from pycocoevalcap.cider.cider import Cider
from pycocoevalcap.spice.spice import Spice

class COCOEvalCap:
    def __init__(self, coco, cocoRes):
        self.evalImgs = []
        self.eval = {}
        self.imgToEval = {}
        self.coco = coco
        self.cocoRes = cocoRes
        self.params = {'image_id': coco.getImgIds()}

    def evaluate(self):
        imgIds = self.params['image_id']
        # imgIds = self.coco.getImgIds()
        gts = {}
        res = {}
        for imgId in imgIds:
            gts[imgId] = self.coco.imgToAnns[imgId]
            res[imgId] = self.cocoRes.imgToAnns[imgId]

        # =================================================
        # Set up scorers
        # =================================================
        print('tokenization...')
        tokenizer = PTBTokenizer()
        gts  = tokenizer.tokenize(gts)
        res = tokenizer.tokenize(res)

        # =================================================
        # Set up scorers
        # =================================================
        print('setting up scorers...')
        scorers = [
            (Bleu(4), ["Bleu_1", "Bleu_2", "Bleu_3", "Bleu_4"]),
            (Meteor(),"METEOR"),
            (Rouge(), "ROUGE_L"),
            (Cider(), "CIDEr"),
            (Spice(), "SPICE")
        ]

        # =================================================
        # Compute scores
        # =================================================
        for scorer, method in scorers:
            print ('computing %s score...'%(scorer.method()))
            score, scores = scorer.compute_score(gts, res)
            if type(method) == list:
                for sc, scs, m in zip(score, scores, method):
                    self.setEval(sc, m)
                    self.setImgToEvalImgs(scs, gts.keys(), m)
                    print("%s: %0.3f"%(m, sc))
            else:
                self.setEval(score, method)
                self.setImgToEvalImgs(scores, gts.keys(), method)
                print("%s: %0.3f"%(method, score))
        self.setEvalImgs()

    def setEval(self, score, method):
        self.eval[method] = score

    def setImgToEvalImgs(self, scores, imgIds, method):
        for imgId, score in zip(imgIds, scores):
            if not imgId in self.imgToEval:
                self.imgToEval[imgId] = {}
                self.imgToEval[imgId]["image_id"] = imgId
            self.imgToEval[imgId][method] = score

    def setEvalImgs(self):
        self.evalImgs = [eval for imgId, eval in self.imgToEval.items()]

# %%
from pycocotools.coco import COCO
from pycocoevalcap.eval import COCOEvalCap

annotation_file = '/kaggle/working/captions.json'
results_file = '/kaggle/working/gen_captions.json'

# create coco object and coco_result object
coco = COCO(annotation_file)
coco_result = coco.loadRes(results_file)

# create coco_eval object by taking coco and coco_result
coco_eval = COCOEvalCap(coco, coco_result)

# evaluate on a subset of images by setting
# coco_eval.params['image_id'] = coco_result.getImgIds()
# please remove this line when evaluating the full validation set
coco_eval.params['image_id'] = coco_result.getImgIds()

# evaluate results
# SPICE will take a few minutes the first time, but speeds up due to caching
coco_eval.evaluate()

# print output evaluation scores
for metric, score in coco_eval.eval.items():
    print(f'{metric}: {score:.3f}')
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 39388 tokens at 157304.24 tokens per second.
# PTBTokenizer tokenized 40781 tokens at 156502.91 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 36493, 'reflen': 34975, 'guess': [36493, 35565, 34638, 33711], 'correct': [12861, 3148, 996, 316]}
# ratio: 1.0434024303073326
# Bleu_1: 0.352
# Bleu_2: 0.177
# Bleu_3: 0.096
# Bleu_4: 0.054
# computing METEOR score...
# METEOR: 0.128
# computing Rouge score...
# ROUGE_L: 0.270
# computing CIDEr score...
# CIDEr: 0.313
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/opt/conda/lib/python3.10/site-packages/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.8 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [1.4 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.7 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.7 sec].
# Threads( StanfordCoreNLP ) [03:13.467 minutes]
# Parsing test captions
# Threads( StanfordCoreNLP ) [03:43.885 minutes]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 7.136 min
# SPICE: 0.086
# Bleu_1: 0.352
# Bleu_2: 0.177
# Bleu_3: 0.096
# Bleu_4: 0.054
# METEOR: 0.128
# ROUGE_L: 0.270
# CIDEr: 0.313
# SPICE: 0.086

# %% [markdown]
# ## Final Output
# This section displays the captions generated by the trained image captioning model for the entire test dataset. Each image in the test dataset is shown along with its corresponding generated caption, providing a comprehensive view of the model's performance on unseen images.
#
# - **Display Captions**: Captions generated by the model for each image in the test dataset are displayed, showcasing the model's ability to describe a variety of images.
#
# - **Comprehensive Evaluation**: The displayed captions allow for a qualitative evaluation of the model's performance, highlighting its strengths and areas for improvement.

# %%
for i in range(len(predicted_captions)):
    print("Caption for Image ",test_image_names[i],": ",predicted_captions[i],"\n")
# Out:
# Caption for Image  test_1.jpg :  The image is of a city street. There is a street light in the street with a large The building is painted yellow and black. There is a car parked on the side of the street. There are many
#
# Caption for Image  test_2.jpg :  A person is standing on a beach on a sunny day. The man is wearing a black jacket and blue jean pants. The man is wearing a black jacket and black pants. The person is wearing a black jacket and
#
# Caption for Image  test_3.jpg :  This picture is taken inside of a living room of a home. A small white t.v. is sitting on a desk with a white painted wall behind it. There is a white and black keyboard sitting on the desk in
#
# Caption for Image  test_4.jpg :  The train is pulling into the station. The train is yellow and black. The train is pulling into the station. The train is yellow and black. The train is pulling into the station. The train is yellow and black.
#
# Caption for Image  test_45.jpg :  A person is standing on a sidewalk holding a ski slope. The woman is wearing a black jacket and black pants. The person is wearing a black jacket and black pants. The person is holding a black umbrella. The umbrella
#
# Caption for Image  test_46.jpg :  The sky is blue and clear. The sky is blue and clear. The sky is blue and clear. The sky is blue and clear. The water is reflecting the water. The water is very and There is a
#
# Caption for Image  test_47.jpg :  A train is on the tracks. The train is yellow and black. The train is pulling into the station. The train is yellow and black. The train is pulling into the station. The train is yellow and black. The train
#
# Caption for Image  test_48.jpg :  This is an image of a city street. The street is and is parked on the street. The bus is white and has a black and white There is a red train on the tracks in front of
#
# Caption for Image  test_49.jpg :  Two elephants are standing in a grassy field on a sunny day. The field is covered with green grass. The grass is green and mostly brown. There is a fence surrounding the field with a few patches of grass. The
#
# Caption for Image  test_50.jpg :  The building is made of cylinder block. There is a clock on the top of the tower. The clock is white with black numbers. There are two windows on the side of the building. The clock is black and white
#
# Caption for Image  test_51.jpg :  The image is of a train on the tracks. The train is yellow and black. The train is pulling into the station. The train is yellow and black. The train is pulling into the station. The train is yellow and
#
# Caption for Image  test_52.jpg :  The people are standing on a grassy field on a sunny day. The man is wearing a black and white striped shirt and black pants. The man is standing in front of a large gray and black line on the
#
# Caption for Image  test_53.jpg :  A table has a white The vase is a and a The vase is and the plate is The vase is and has a and a The vase is and has
#
# Caption for Image  test_54.jpg :  A man is standing on a tennis court playing tennis. He is wearing a black shirt and black shorts. He is holding a racket in his hand. He is wearing a black shirt and black shorts. He is wearing a
#
# Caption for Image  test_55.jpg :  A man is standing in a room with a large on a table. The man is wearing a black and white striped shirt and a black and white striped shirt. There is a red and white cat sitting next
#
# Caption for Image  test_56.jpg :  The table is a white plate with a white plate on it. There is a white plate on the table. There is a white plate on the table. There is a white plate on the table. There is a white
#
# Caption for Image  test_57.jpg :  The motorcycle is parked on the sidewalk. The motorcycle is black. The motorcycle is black. The car is parked on the grass. The motorcycle is black. The car is parked on the grass. The motorcycle is black. The car is
#
# Caption for Image  test_58.jpg :  There is a man surfing. He is wearing a white shirt and black shorts. The man is holding a white surfboard under his head. He is wearing a black and white helmet, and black and black and white shoes. He
#
# Caption for Image  test_59.jpg :  The fire hydrant is painted on the top of a yellow fire hydrant. There is a sign on the pole that has a sign attached to the pole. The sign is black and white. There is a sign on the
#
# Caption for Image  test_60.jpg :  This is a picture of some animals. The animals are giraffes. The giraffes are standing on a grassy field in the grass. The grass is green and the grass is mostly dry and some of the horses are green and
#
# Caption for Image  test_61.jpg :  This is an image of a city street. The street is lined with people. The tracks are made of metal and The train is on the train tracks. The train is yellow and black. The train is pulling into
#
# Caption for Image  test_62.jpg :  The building is made of cylinder block. There is a clock on the clock tower. The clock is black and white. There is a clock on the clock tower. The clock is white with black numbers. The clock is black
#
# Caption for Image  test_63.jpg :  A pizza is on a white plate. The plate is sitting on a table. The table is made of wood and has a white There is a white plate on the table. There is a white plate on the
#
# Caption for Image  test_64.jpg :  The women are sitting in a of a home.  The tablecloth is a brown and white striped The horse is brown and white. The horse is brown and white. The dog is laying on a brown wooden
#
#
# Caption for Image  test_126.jpg :  This is a picture of a train on a train track. The train is pulling into the station. The train is pulling into the station. The train is pulling into the station. The train is pulling into the station. The
#
# Caption for Image  test_127.jpg :  This is a picture of a pet. There is a white plate on the table. The food is brown and white. There is a black and white cat sitting on the couch. There is a black cat sitting on the
#
# Caption for Image  test_128.jpg :  There are people standing in a field. There are people sitting on the grass behind a fence. The man on the left is wearing a black shirt and black pants. The other person is standing on the ground in front
#
# Caption for Image  test_129.jpg :  The giraffe is standing in a grassy field.  The giraffe is brown and white.  The giraffe has a long neck and a black and white  The giraffe has a long brown trunk.  The giraffe has
#
# Caption for Image  test_130.jpg :  There is a man standing in a commercial wearing a black and white shirt, and black and white striped shirt and black pants standing in a black and white The truck is in front of a white and black
#
# Caption for Image  test_131.jpg :  There is a man and a woman on a beach on a sunny day. The man is wearing a black jacket and blue jean pants. He is wearing a black and white helmet, and black and white pants. The man
#
# Caption for Image  test_132.jpg :  The image is of a train station. The train is on the train tracks. There is a train on the track. The train is yellow and black. The train is pulling into the station. The train is yellow and black.
#
# Caption for Image  test_133.jpg :  This is a picture of a cat on a desk. The desk is black and white. The cat is sitting on a brown wooden desk. The desk has a black frame. The window is made of brown wood. The cat
#
# Caption for Image  test_134.jpg :  This is a picture of a cat on a desk. The cat is sitting on a white couch. The cat is gray and black. The cat is gray and black. The cat is laying on a white couch. The cat
#
# Caption for Image  test_135.jpg :  This is a picture of a The is a The is a The is yellow and has black and white stripes. The two horses are standing on a brown wooden The first bench
#
# Caption for Image  test_136.jpg :  This picture is taken outside on a sunny day. A man is riding a motorcycle down a street. The man is wearing a black helmet and a white helmet. The man is wearing a black shirt and black pants. The
#
# Caption for Image  test_137.jpg :  A woman is sitting at a table. The table is made of wood. The woman is wearing a black shirt and a pair of glasses. The glasses are on a table. The table is made of wood. The woman is
#
# Caption for Image  test_138.jpg :  This is a picture of some food. The food is The food is and The plate is sitting on a table. The table is made of wood and has a white There is a white plate
#
# Caption for Image  test_139.jpg :  A man is standing on a tennis court playing tennis. He is wearing a blue and white striped shirt and black shorts. He is holding a racket in his hand. He is wearing a red shirt and black and white
#
# Caption for Image  test_140.jpg :  This is an image of a bathroom. The bathroom is very The bathroom is white with black and white stripes. The sink is white with a white lid on it. The wall is a light brown color. There is
#
# Caption for Image  test_141.jpg :  A woman is standing outside on a tennis court. She is wearing a black shirt and black shorts. The woman is holding a racket in her hands. She is wearing a black shirt and black shorts. The woman is holding
#
# Caption for Image  test_142.jpg :  There are two people standing on a beach. The horse is wearing a black and white striped shirt and a black and white striped shirt. There is a black dog standing in front of a fence. There is a fence
#
# Caption for Image  test_143.jpg :  This is an image of a bedroom. The bedroom has a white bed with a white and black bottom. The desk has a white bed and a black and white pillows. There is a white and black keyboard sitting on
#
# Caption for Image  test_144.jpg :  This is a picture of a wooden table. There is a white plate on the table. The table is made of wood and has a white There is a black and white plate on the table. There is a
#
# Caption for Image  test_145.jpg :  This is a picture of a wooden table. There is a white plate on the table. The table is made of wood and has a white There is a black and white plate on the table. There is a
#
# Caption for Image  test_146.jpg :  This is a picture of a baseball game. The player is swinging a baseball bat. The player is wearing a baseball mitt on a baseball field. The player is wearing a red shirt and black shorts. The man is wearing
#
# Caption for Image  test_147.jpg :  The image is of a man and a man riding a horse. The man is wearing a white shirt and black shorts. The man is wearing a black helmet and black pants. The man is wearing a black helmet and
#
# Caption for Image  test_148.jpg :  A stop sign is in the middle of a street. The building has a large white with a clock on it. The clock is and There is a sign on the pole that says There is
#
# Caption for Image  test_149.jpg :  This is an image of a river. The river is dark brown and white. The elephant has a long brown trunk. The elephant has big tusks. The elephant has big tusks. The elephant has big tusks. The elephant has big
#
# Caption for Image  test_150.jpg :  A cat is laying on the couch. The cat is laying on the couch. The cat is laying on the couch. The cat is laying on the couch. The cat is laying on the couch. The cat is laying on
#
# Caption for Image  test_151.jpg :  A woman is sitting on a bench. The bench is made of brown and brown bricks. The man is wearing a black and white striped shirt. The man is wearing a black and white striped shirt. The man has a
#
# Caption for Image  test_152.jpg :  A man is standing in front of a man and a man in a black shirt and black pants is standing in front of a fence. The man is wearing a black shirt and black pants. The man is wearing
#
# Caption for Image  test_153.jpg :  A of sits on a sidewalk in front of a building. The building is a tall building with a tall tower on the top of a pole. The pole is and has a black and white
#
# Caption for Image  test_154.jpg :  The image is of a city with a large of the There is a clock on the top of the tower. The clock tower is made of stone. There is a clock on the top of the tower.
#
# Caption for Image  test_155.jpg :  A large brown and white cow is standing next to a large brown wooden fence. There is a tall brown building with a white and black bird sitting on top of a black and white There is a brown
#
# Caption for Image  test_156.jpg :  A man is standing in a room holding a game of in his hand. He is wearing a black and white striped shirt and a black and white striped shirt. He is holding a red and white and black
#
# Caption for Image  test_157.jpg :  The zebra is black and white. There are two zebras in the image. The zebras eyes are open. There is a tree to the left of the zebras and a zebra to the left. The zebra on the left is
#
# Caption for Image  test_158.jpg :  This is a picture of a baseball game. The player is standing on a baseball field. The player is wearing a white shirt and a black and white striped shirt. He is swinging a bat in his hand. He is
#
# Caption for Image  test_159.jpg :  There is a train traveling on a road. The train is yellow and white. The train is pulling into the station. The train is red. The train is pulling into the station. The train is pulling into the station. The
#
# Caption for Image  test_160.jpg :  A laptop is sitting on a desk with a white desk. There is a white desk with a laptop computer sitting on top of it. There is a white desk with a black keyboard sitting in front of it.
#
# Caption for Image  test_161.jpg :  This is a picture of a The picture is of a black and white There is a white and black cat sitting on the table. The cat is gray and has black and white stripes. The cat is
#
# Caption for Image  test_162.jpg :  The man is standing in a field. The man is wearing a black shirt and blue jean pants. The man is wearing a black shirt and blue jean pants. The man is wearing a black shirt and black pants. The
#
# Caption for Image  test_163.jpg :  A clock is sitting on a white painted blue The clock is white and blue and has a black The clock is black and white. There is a clock on the clock tower. The clock is white with
#
# Caption for Image  test_164.jpg :  The image is of a man and a horse and carriage on the beach. The man is riding on the street. The man is wearing a black jacket and black pants. The man is wearing a black helmet and black
#
# Caption for Image  test_165.jpg :  A woman is sitting on a bench. The bench is made of wood and is sitting on the bench. The bench is made of wood and is covered in snow. The bench is made of wood and is covered in
#
# Caption for Image  test_166.jpg :  A group of people are standing on a sidewalk in a parking lot. The street is lined with many cars and cars parked along the street. There is a man in a black and white shirt standing in front of
#
# Caption for Image  test_167.jpg :  This is an image of a city street. The street is and is parked on the street. The bus is white and has a black and white There is a red and white train on the tracks. There
#
# Caption for Image  test_168.jpg :  A large white building with a clock tower sits in a The clock is white with black numbers. The clock is black and white. The clock is on the top of the tower. The clock is and
#
# Caption for Image  test_169.jpg :  The street is made of brick and has a sign that says The sign is a The sign is white with black letters and the numbers on the sign is a The sign is attached to
#
# Caption for Image  test_170.jpg :  The image is of a train on a train track. The train is pulling into the station. The train is yellow and black. The train is pulling into the station. The train is yellow and black. The train is pulling
#
# Caption for Image  test_171.jpg :  A large black bear is standing in a field full of bushes. The bear is looking to the left. The bear is looking to the left. The bear is looking to the left. The bear is laying down. The bear
#
# Caption for Image  test_172.jpg :  A man in a black wet suit is standing on a beach on a sunny day. He is wearing a black and white shirt, and black and white pants. He is standing on a beach holding a white surfboard with
#
# Caption for Image  test_173.jpg :  The image is of a train station. The train is on the train tracks. The train is yellow and black. The train is pulling into the station. The train is yellow and black. The train is pulling into the station.
#
# Caption for Image  test_174.jpg :  This is a picture of a wooden table. There is a white plate on top of a table. The table is made of wood and has a white There is a white and black keyboard with a silver fork
#
# Caption for Image  test_175.jpg :  A group of people are sitting on a table. The table is made of wood and has two chairs. There is a man sitting on a desk next to a black bag. The man is wearing a black and white
#
# Caption for Image  test_176.jpg :  A man and woman are sitting at a table in a restaurant. The man is wearing a black shirt and a pair of glasses. The woman is holding a white Wii remote. She is wearing a black and white jacket.
#
# Caption for Image  test_177.jpg :  A white building with a clock is in the middle of a The building is a and has a clock on the top of it. The clock is black and white. There is a clock on the pole
#
# Caption for Image  test_178.jpg :  Four men are standing in a room with a large and brown and white striped is sitting in front of a large and a on the table. A man is sitting on the table. A man
#
# Caption for Image  test_179.jpg :  A white cat with black hair is sitting on a wooden table. The desk is black and has a black and white striped There is a on the floor under the cat. The cat is sitting on the
#
# Caption for Image  test_180.jpg :  There are people riding horses on the horses. The horses are wearing white hats. The men are wearing black shirts and pants. The man on the horse is wearing a black jacket and black pants. The other person is standing
#
# Caption for Image  test_181.jpg :  A man is sitting on a chair wearing a black and white shirt and a white apron. The man is holding a white game controller in his hand. The man is wearing a black shirt and a white shirt. The
#
# Caption for Image  test_182.jpg :  The horses are standing on a grassy field. The horse is brown and white. The horse is brown and white. The horse is brown and white. The horse is brown and white. The dog is wearing a black helmet. The
#
# Caption for Image  test_183.jpg :  A white table with a white table cloth is sitting on a table. The desk is black and has a white on it. There is a black and white dog sitting on a desk with a black on
#
# Caption for Image  test_184.jpg :  This is an image of a desk that is a The computer screen is white and black. The cat is sitting on a desk with a white keyboard in front of it. The cat is gray and has black
#
# Caption for Image  test_185.jpg :  A man is standing on a platform waiting for a street. The man is wearing a black jacket and blue jean pants. The man is wearing a black shirt and black pants. The man is wearing a black jacket and
#
# Caption for Image  test_186.jpg :  The image is of a brown horse with a black and white face and a brown The bird is black and white. The cat is laying on the ground. The cat is brown and white. The cat is sitting
#
# Caption for Image  test_187.jpg :  The street is crowded with many cars and cars parked along the street. There is a street sign on the street in front of the building. The building is made of brick and has a clock on the top of
#
# Caption for Image  test_188.jpg :  The woman is standing in front of a white and blue The woman is wearing a white shirt and black shorts. The woman is holding a racket in her hand. The court is white with a red and white
#
# Caption for Image  test_189.jpg :  This is a picture of a horse and a dog. The dog is a black and white dog. The dog is black and white. The dog is black and white. The dog is black and white. The dog is black
#
# Caption for Image  test_190.jpg :  This is a picture of a street. There is a bus parked on the street. The bus is white and has a black on the side of it. There is a red and white sign on the side of
#
# Caption for Image  test_191.jpg :  The table is a and a The table is covered with a brown and white bowl. The vase is a and The vase is sitting on a table. The table is made of metal. The table
#
# Caption for Image  test_192.jpg :  This is a picture of a bathroom. The bathroom is very The bathroom is white with black and white stripes. The sink is white and the lid is open. The toilet is white. There is a toilet in the
#
# Caption for Image  test_193.jpg :  A man is standing outside on a sunny day. He is wearing a black jacket and black pants. He is wearing a black and white striped shirt and black pants. The man is standing in front of a large gray
#
# Caption for Image  test_194.jpg :  This is a picture of a bathroom. The bathroom is very plain. The walls are made of tiles. The bathroom is made of wood and has a white toilet on it. There is a white toilet in the bathroom. The
#
# Caption for Image  test_195.jpg :  A person wearing a black jacket and black pants is standing on a sidewalk holding a black umbrella. The umbrella is black and white and has a black The man is wearing a black jacket and black pants. The
#
# Caption for Image  test_196.jpg :  The sky is blue and partly cloudy. The clouds are white. The sky is partly cloudy and mostly overcast. The runway is parked on the side of the street. The bus is white and has a black and white train
#
# Caption for Image  test_197.jpg :  This is a picture of a wooden table. There is a white plate on the table. The vase is white and has a black There is a white plate on the table. The vase is sitting on the table.
#
# Caption for Image  test_198.jpg :  The image is of a man and a woman standing in the snow. The person is wearing a black jacket and black pants. The person is wearing a black jacket and black pants. The person is holding a black umbrella.
#
# Caption for Image  test_199.jpg :  This is a picture of a black and white cat sitting on a table. There is a white plate on the table. There is a black and white cat sitting on the chair. There is a black and white cat
#
# Caption for Image  test_200.jpg :  This is a picture of a cat on a couch. The cat is sitting on a table. The cat is gray and black. The cat is laying on the couch. The cat is laying on the couch. The cat is
#
# Caption for Image  test_201.jpg :  The image is of a public square. The building is very The building is made of brick. The train is The train is white. The train has windows on the side of the train cars. The train is
#
# Caption for Image  test_202.jpg :  This is an image of a river. The river is a The man is wearing a black shirt and gray pants. The man has a black hat on and a black and white striped shirt. There is a man
#
# Caption for Image  test_203.jpg :  A stop sign is standing on a street light brown and white brick building. A sign is on the pole that is written in the middle of the road. A tall green tree is standing near the street in front
#
# Caption for Image  test_204.jpg :  A man is standing outside on a sunny day. He is wearing a white shirt and a white and white striped shirt. He is holding a red and white racket in his hand. The man is wearing a black shirt
#
# Caption for Image  test_205.jpg :  A man is sitting on a bench. The bench is made of metal. The man is wearing a black jacket. The man is wearing a black jacket and blue jeans. The man is wearing a black shirt and black pants.
#
# Caption for Image  test_206.jpg :  A man is sitting at a table in a restaurant. The man is wearing a white shirt and a pair of glasses and a white apron. The man is holding a white game controller in his hand. The man is
#
# Caption for Image  test_207.jpg :  The kitchen is clean and The walls are white and the walls are white. The walls are white. The walls are white. The floor is made of tiles. The floor is made of wood and has a white
#
# Caption for Image  test_208.jpg :  A vase is sitting on a table. The vase is black and has white flowers on it. There are two glasses on the table. The table is made of metal. The table is made of wood and has a white
#
# Caption for Image  test_209.jpg :  This is an image of a river. The river is a The horse is brown and white. The horse is brown and white. The horse is brown and white. The dog is laying on the grass. The dog is
#
# Caption for Image  test_210.jpg :  A train is on the train tracks. The train is yellow and black. The train is pulling into the station. The train is yellow and black. The train is pulling into the station. The train is yellow and black. The
#
# Caption for Image  test_211.jpg :  This is a picture of a cat on the desk in a room. There is a white and black cat sitting on the chair. There is a white dog sitting on a desk with a brown dog in front of
#
# Caption for Image  test_212.jpg :  This is an image of a city street. The street is lined with people. The train is pulling into the station. The train is yellow and black. The train is pulling into the station. The train is yellow and black.
#
# Caption for Image  test_213.jpg :  A man is standing in front of a man and a white shirt and black pants standing on a sidewalk near a sidewalk. A man is sitting on a bench outside of a building. The man is wearing a black
#
# Caption for Image  test_214.jpg :  a bunch of cows are on the road. there are some some green and some are green and the trees are green and brown. The trees are green and brown. The pole is a The pole is brown
#
# ...
#
# Caption for Image  test_859.jpg :  A small black bird is standing on the grass near a tree. The tree is starting to There is a small stream next to the grass in the background. The ground is covered in snow. The snow is white.
#
# Caption for Image  test_860.jpg :  The image is of a man and a woman standing on a beach with a skateboard in his hand. He is wearing a black wet suit. He is standing on the grass and a large body of water with a
#
# Caption for Image  test_861.jpg :  A man is standing outside on a sunny day. He is wearing a black jacket and black pants. He is wearing a black and white striped shirt and black pants. The man is standing in front of a large gray
#
# Caption for Image  test_862.jpg :  A little girl is sitting on a white couch. The man is wearing a black shirt and a pair of glasses. The glasses are on a brown wooden table. The desk is made of wood. The cat is gray and
#
# Caption for Image  test_863.jpg :  A man is sitting on a bench. The bench is made of brown and gray brick. There is a man standing by the horse. The man is wearing a black shirt and blue jeans. The man is wearing a black
#
# Caption for Image  test_864.jpg :  A black and white dog is standing in front of a building. There is a white building behind the fire hydrant. There is a white car parked on the street. The car is a and a of
#
# Caption for Image  test_865.jpg :  are grazing in a grassy area.  The field is covered with green grass and green grass.  The road is covered with a green and yellow line dividing  The road is covered with a green and yellow
#
# Caption for Image  test_866.jpg :  The street is crowded with people. Two people are sitting on a motorcycle. The motorcycle is red and white. The man on the motorcycle is wearing a black jacket and blue jean pants. The man is wearing a black helmet
#
# Caption for Image  test_867.jpg :  A wooden bench sits in a room. There is a large white building with a white painted blue and blue on top of it. There is a white and black bag sitting on the table.
#
# Caption for Image  test_868.jpg :  This is a picture of a train on a train track. The train is pulling into the station. The train is yellow and black. The train is pulling into the station. The train is yellow and black.
The train is yellow and black. The train is pulling into the station. The train is yellow and black. The train is pulling into the station. The train is yellow and black. The train
#
# Caption for Image  test_890.jpg :  A man is standing on a beach on a sunny day. The man is wearing a black jacket and black pants. He is wearing a black shirt and black pants. The man is wearing a black shirt and black pants.
#
# Caption for Image  test_891.jpg :  Three people are standing in a room of a home. A man in a white shirt and black pants is standing in front of a white and black bag sitting on a chair. A man is sitting on a brown
#
# Caption for Image  test_892.jpg :  The desk is made of wood. The desk has a white computer and black handle. The cat is sitting on the desk. The desk is made of wood and has a black frame. The window is made of wood and
#
# Caption for Image  test_893.jpg :  This is an image of a runway. The runway is painted white. The runway is white. The bus is white. The bus is white. The bus is white. The bus is white. The bus is white. The bus is white.
#
# Caption for Image  test_894.jpg :  A large white and blue truck is parked on a street in front of a building. The building is a tall brick building with a white sign with a white face and a yellow sign is sitting on the ground
#
# Caption for Image  test_895.jpg :  A white and black cat is sitting on a white couch. The cat is gray and black and white stripes. The cat has white fur on it's paws. The cat is laying on the side of the bed. There is
#
# Caption for Image  test_896.jpg :  A man is standing in a room with a laptop computer and a laptop computer and a on a desk. The desk is made of wood and has a black and white laptop computer with a white stripe down
#
# Caption for Image  test_897.jpg :  A man is sitting in a parking lot. He is wearing a black and white striped shirt and black pants. The man is wearing a black shirt and black pants. The man is wearing a black shirt and black pants.
#
# Caption for Image  test_898.jpg :  A white plate is sitting on a table. The table is made of wood and has two of broccoli. The broccoli is and is sitting on a table. The table is made of wood and has two
#
# Caption for Image  test_899.jpg :  The image is a of a fire hydrant on a sidewalk. The street is covered in a The building is covered with a brown roof. The sign has a sign on the pole. The sign is attached to
#
# Caption for Image  test_900.jpg :  The clock is very ornate. The clock is white. The clock is on the top of the tower. The clock is white with black numbers. There are two large windows on the front of the building. The clock is white
#
# Caption for Image  test_901.jpg :  The truck is driving down the street. The bus is white and has a black and white sign with a red stripe on the side of it. There is a red and white sign on the side of the road.
#
# Caption for Image  test_902.jpg :  Four skiers are on a ski slope. The ski slope is covered with snow. The snow is white. The skier is wearing a black wet suit. The skier is wearing a black jacket and black pants. The man is wearing
#
# Caption for Image  test_903.jpg :  The street is lined with people. The tracks are made of gray and white and yellow and yellow umbrellas on the side of the train. The train is pulling into the station. The train is pulling into the station. The
#
# Caption for Image  test_904.jpg :  The picture is taken outside on a sunny day. A man is standing on a sidewalk holding a black umbrella. The umbrella is white and black. There is a black car parked on the street. The man is wearing a
#
# Caption for Image  test_905.jpg :  A man is standing on a beach on a sunny day. He is wearing a black jacket and black pants. He is wearing a black and white striped shirt and black pants. The man is wearing a black shirt and
#
# Caption for Image  test_906.jpg :  There are people standing on a ski slope. The person on the left is wearing a black jacket and black pants. The person is wearing a black jacket and black pants. The person is standing on the grass near the
#
# Caption for Image  test_907.jpg :  A large brown cow with brown spots is standing on a dirt field on a sunny day. The bird is standing on a brown wooden bench and a brown horse that is standing on a brown wooden bench with a
#
# Caption for Image  test_908.jpg :  This is an image of a bird. The giraffe is a The giraffe is brown and white. The giraffe has long neck and legs. The giraffe is standing in the middle of a grassy field. The giraffe is standing
#
